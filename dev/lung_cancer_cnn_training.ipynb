# %% [markdown]
# <div style="
#     background-color:#0b1f3a;
#     color:#ffffff;
#     padding:20px;
#     border-radius:12px;
#     font-size:34px;
#     font-weight:700;
#     text-align:center;
# ">
# 🫁 CNN Training for Lung Cancer Detection
# </div>

# %%
#!pip install tensorflow

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import saving

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = "datasets"

train_datagen = ImageDataGenerator(
    rescale=1./255,
    zoom_range=0.15,
    horizontal_flip=True
)

training_set = train_datagen.flow_from_directory(
    f"{dataset_path}/train",
    target_size=(128, 128),   # ✅ increased resolution
    batch_size=32,
    class_mode="categorical"
)

val_datagen = ImageDataGenerator(rescale=1./255)

validation_set = val_datagen.flow_from_directory(
    f"{dataset_path}/val",
    target_size=(128, 128),   # ✅ must match training
    batch_size=32,
    class_mode="categorical"
)
# Out:
# Found 876 images belonging to 3 classes.
# Found 221 images belonging to 3 classes.

# %%
cnn = tf.keras.models.Sequential()

cnn.add(tf.keras.layers.Conv2D(
    filters=32, kernel_size=3, activation='relu',
    input_shape=(128, 128, 3)
))
cnn.add(tf.keras.layers.MaxPooling2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPooling2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPooling2D(pool_size=2, strides=2))

cnn.add(tf.keras.layers.Flatten())

cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))
cnn.add(tf.keras.layers.Dropout(0.5))

cnn.add(tf.keras.layers.Dense(units=3, activation='softmax'))

cnn.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['categorical_accuracy']
)

cnn.summary()

cnn.fit(
    training_set,
    validation_data=validation_set,
    epochs=100   # ✅ unchanged
)

print(training_set.class_indices)
# Out:
# C:\Users\subha\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 126, 126, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 61, 61, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 30, 30, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 28, 28, 32)          │           9,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 14, 14, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 6272)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │         802,944 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 3)                   │             387 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 822,723 (3.14 MB)
#  Trainable params: 822,723 (3.14 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - categorical_accuracy: 0.5377 - loss: 0.9688 - val_categorical_accuracy: 0.5385 - val_loss: 0.8931
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 520ms/step - categorical_accuracy: 0.6130 - loss: 0.8483 - val_categorical_accuracy: 0.6244 - val_loss: 0.8434
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 509ms/step - categorical_accuracy: 0.6689 - loss: 0.7789 - val_categorical_accuracy: 0.6471 - val_loss: 0.8182
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 512ms/step - categorical_accuracy: 0.6838 - loss: 0.7329 - val_categorical_accuracy: 0.6968 - val_loss: 0.7021
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 491ms/step - categorical_accuracy: 0.7112 - loss: 0.7454 - val_categorical_accuracy: 0.7104 - val_loss: 0.7900
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 563ms/step - categorical_accuracy: 0.7226 - loss: 0.6877 - val_categorical_accuracy: 0.7919 - val_loss: 0.5847
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - categorical_accuracy: 0.7203 - loss: 0.6657 - val_categorical_accuracy: 0.7376 - val_loss: 0.6108
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 521ms/step - categorical_accuracy: 0.7626 - loss: 0.6010 - val_categorical_accuracy: 0.7647 - val_loss: 0.5593
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 547ms/step - categorical_accuracy: 0.7557 - loss: 0.5787 - val_categorical_accuracy: 0.8190 - val_loss: 0.4803
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 18s 626ms/step - categorical_accuracy: 0.7865 - loss: 0.5104 - val_categorical_accuracy: 0.8371 - val_loss: 0.4093
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s 556ms/step - categorical_accuracy: 0.7934 - loss: 0.5353 - val_categorical_accuracy: 0.8326 - val_loss: 0.4676
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 16s
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 494ms/step - categorical_accuracy: 0.9680 - loss: 0.0891 - val_categorical_accuracy: 0.9548 - val_loss: 0.1280
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 542ms/step - categorical_accuracy: 0.9384 - loss: 0.1795 - val_categorical_accuracy: 0.9548 - val_loss: 0.1671
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 492ms/step - categorical_accuracy: 0.9578 - loss: 0.1160 - val_categorical_accuracy: 0.9548 - val_loss: 0.1397
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 515ms/step - categorical_accuracy: 0.9578 - loss: 0.1010 - val_categorical_accuracy: 0.9593 - val_loss: 0.1252
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 485ms/step - categorical_accuracy: 0.9612 - loss: 0.0955 - val_categorical_accuracy: 0.9638 - val_loss: 0.1306
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 535ms/step - categorical_accuracy: 0.9692 - loss: 0.0986 - val_categorical_accuracy: 0.9638 - val_loss: 0.1397
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 492ms/step - categorical_accuracy: 0.9589 - loss: 0.0983 - val_categorical_accuracy: 0.9502 - val_loss: 0.1374
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 534ms/step - categorical_accuracy: 0.9646 - loss: 0.0939 - val_categorical_accuracy: 0.9593 - val_loss: 0.1423
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 484ms/step - categorical_accuracy: 0.9589 - loss: 0.0993 - val_categorical_accuracy: 0.9548 - val_loss: 0.1339
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 542ms/step - categorical_accuracy: 0.9623 - loss: 0.1002 - val_categorical_accuracy: 0.9548 - val_loss: 0.1456
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 482ms/step - categorical_accuracy: 0.9658 - loss: 0.0842 - val_categorical_accuracy: 0.9683 - val_loss: 0.1370
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 517ms/step - categorical_accuracy: 0.9555 - loss: 0.0998 - val_categorical_accuracy: 0.9593 - val_loss: 0.1730
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 498ms/step - categorical_accuracy: 0.9658 - loss: 0.1007 - val_categorical_accuracy: 0.9683 - val_loss: 0.1183
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 14s 513ms/step - categorical_accuracy: 0.9578 - loss: 0.1146 - val_categorical_accuracy: 0.9638 - val_loss: 0.1428
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 15s 517ms/step - categorical_accuracy: 0.9646 - loss: 0.0919 - val_categorical_accuracy: 0.9593 - val_loss: 0.1675
# {'Benign': 0, 'Malignant': 1, 'Normal': 2}

# %%
import os
os.makedirs("models", exist_ok=True)
cnn.save("models/cnn-100epochs.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Test the trained CNN model

import numpy as np
import os
import random
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import load_model

os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'

# Paths
DATASET_PATH = "datasets/val"   # using validation as test
MODEL_PATH = "models/cnn-100epochs.h5"

# Labels (MUST match training folders)
labels = ["Benign", "Malignant", "Normal"]

# Pick a random class folder
random_class = random.choice(os.listdir(DATASET_PATH))
class_path = os.path.join(DATASET_PATH, random_class)

# Pick a random image
random_image = random.choice(os.listdir(class_path))
image_path = os.path.join(class_path, random_image)

# Load and preprocess image
test_image = image.load_img(image_path, target_size=(128, 128))
test_image = image.img_to_array(test_image)
test_image = test_image / 255.0
test_image = np.expand_dims(test_image, axis=0)

# Load model
cnn = load_model(MODEL_PATH)

# Predict
result = cnn.predict(test_image)
predicted_class = labels[np.argmax(result)]

print("Image path:", image_path)
print("Prediction probabilities:", result)
print("Predicted class:", predicted_class)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# Image path: datasets/val\Normal\Normal case (150).jpg
# Prediction probabilities: [[8.1195707e-05 1.4674968e-05 9.9990416e-01]]
# Predicted class: Normal

# %%
print(training_set.class_indices)
# Out:
# {'Benign': 0, 'Malignant': 1, 'Normal': 2}
